# %% [markdown]
# ### p.151~p.160

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
sp.stats.binom.pmf(k=1, n=2, p=0.5)
# Out:
# 0.5

# %%
sp.stats.binom.rvs(n=10, p=0.2, size=5)
# Out:
# array([1, 1, 3, 3, 2])

# %%
binomial = sp.stats.binom(n=10, p=0.2)

# %%
m = np.arange(1,10,1)
pmf_binomial = binomial.pmf(k=m)

# %%
plt.plot(m, pmf_binomial, color='black')

# %%
def mybinom(p=0.2, myn=10,color='black'):
    """횟수 n을 받아서 그래프 반환"""
    m = np.arange(0,myn+1,1)
    mypmf = sp.stats.binom(myn, p=p).pmf(k=m)
    return plt.plot(m, mypmf, color)

# %%
mybinom(myn=10, color='red')
mybinom(myn=20, color='blue')
mybinom(myn=50, color='gray')

# %%
mybinom(p=0.5, myn=10, color='red')
mybinom(p=0.5, myn=20, color='blue')
mybinom(p=0.5, myn=50, color='gray')
mybinom(p=0.5, myn=70, color='yellow')

# %% [markdown]
# ### 큰 수의 법칙
# 어떤 시행에서 사건 $A$가 일어날 확률이 $p$일 때, $n$회의 독립시행에서 사건 $A$가 일어나는 횟수를 $X$라고 하면, 충분히 작은 양수 $h$에 대하여,
#
# $$ \lim_{n \rightarrow \infty} P(|\frac{X}{n} -p|<h) =1$$

# %% [markdown]
# #### $X \sim B(n, \frac{1}{6} )$에 대하여 위의 정리를 확인해보자

# %%
h = 0.1
p = 1/6

# %%
n= 10

# %%
abs(-2)
# Out:
# 2

# %%
def disx(val, n, h, p):
    """확률변수의 값이 원하는 범위에 들었는지 판단"""
    return abs((val/n) - p)< h

# %%
sp.stats.binom.pmf(k=1, n=10, p=p)+sp.stats.binom.pmf(k=2, n=10, p=p)
# Out:
# 0.6137212149814141

# %%
def cal(num,p,h):
    result = 0
    for i in range(num+1):
        if disx(i,num,h,p):
            result = result + sp.stats.binom.pmf(k=i, n=num, p=p)
    return result

# %% [markdown]
# #### $p=1/6 ,~ h=0.1$ 인 상태에서 $n$ 을 증가시키며 값을 확인해보기

# %%
cal(10,1/6,0.1)
# Out:
# 0.6137212149814141

# %%
cal(20,1/6,0.1)
# Out:
# 0.7677392444488867

# %%
cal(30,1/6,0.1)
# Out:
# 0.856824157154791

# %%
cal(50,1/6,0.1)
# Out:
# 0.9454534099957239

# %% [markdown]
# #### $p=1/6 ,~ h=0.01$ 인 상태에서 $n$ 을 증가시키며 값을 확인해보기

# %%
cal(50,1/6,0.01)
# Out:
# 0.15102672215839338

# %%
cal(100,1/6,0.01)
# Out:
# 0.2117498900497256

# %%
cal(1000,1/6,0.01)
# Out:
# 0.6039732757226145

# %%
cal(10000,1/6,0.01)
# Out:
# 0.9927076466918039

# %% [markdown]
# #### $p=1/2 ,~ h=0.1$ 인 상태에서 $n$ 을 증가시키며 값을 확인해보기

# %%
cal(10,1/2,0.1)
# Out:
# 0.6562500000000007

# %%
cal(30,1/2,0.1)
# Out:
# 0.7995115779340211

# %%
cal(50,1/2,0.1)
# Out:
# 0.8810795474405578
